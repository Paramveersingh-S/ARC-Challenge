# %% [markdown]
# # ARC Prize 2026 - Active Hypothesis Testing
# This notebook contains the complete agent for ARC-AGI-2 and ARC-AGI-3.

# %%
import os
import sys
sys.path.append('/kaggle/working/src')

from evaluate import evaluate_on_training, format_submission
from solver import solve_all
from pathlib import Path

# DATA_ROOT = Path('/kaggle/input/arc-prize-2026/arc-agi2/evaluation')
# predictions = solve_all(DATA_ROOT)
# format_submission(predictions, 'submission.json')
